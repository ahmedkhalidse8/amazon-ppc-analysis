# %% [markdown]
# # Amazon PPC Data Cleaning
#
# ## Objective
#
# Clean raw Amazon Sponsored Products advertising data and business reports
# before analysis.
#
# Steps:
# - Standardize column names
# - Convert numeric fields
# - Remove currency and percentage formatting
# - Extract date information
# - Save cleaned datasets

# %%
import pandas as pd
import numpy as np

# %%
ads = pd.read_csv("../data/raw/custom_ads.csv")

business = pd.read_csv("../data/raw/business_reports.csv")

print(ads.shape)
print(business.shape)
# Out:
# (2332, 20)
# (1, 25)
